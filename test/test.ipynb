# %%
# !nvidia-smi
# Out:
# Wed Jun  7 11:00:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:0B:00.0 Off |                  N/A |
# |  0%   49C    P0    35W / 170W |      0MiB / 12288MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
# cuda 환경 확인 -> rocm도 cuda호환됨.
torch.cuda.is_available()
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
cv2.__version__
# Out:
# '4.7.0'

# %%
lenna = cv2.imread('./data/lenna.bmp')
# 깃허브 데이터에서 읽기
lenna = cv2.cvtColor(lenna, cv2.COLOR_BGR2RGB)
plt.imshow(lenna)

# %%
rose = cv2.imread('../../drive/MyDrive/Colab/rose.bmp')
rose = cv2.cvtColor(rose, cv2.COLOR_BGR2RGB)
plt.imshow(rose)

# %%
DRIVE_PATH = '../../drive/MyDrive/Colab/'

# %%
with open(DRIVE_PATH + 'test.txt', 'w') as f:
    f.write('abcdefg')
